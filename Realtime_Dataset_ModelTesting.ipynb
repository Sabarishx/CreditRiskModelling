# %%
import PreProcessing_PD_Model as prepo

# %%
df=prepo.pd.read_csv(r"C:\Users\sabar\OneDrive\Documents\AI_ML\Credit Risk Analytics\Risk Dataset\credit_risk_dataset.csv")
df.head(2)

# %%
scalable_data, inputs, actuals, balanced_input, balanced_actual = prepo.ModelPreProcessing(df)

# %%
inputs.shape

# %%
balanced_input.shape

# %%
import pickle

# %%
with open('Logistic_PD_Model.pkl','rb') as file:
    Logistic_PD_Model=pickle.load(file)

# %%
with open('XGBoost_PD_Model.pkl','rb') as file:
    XGBoost_PD_Model=pickle.load(file)

# %%
with open('RF_PD_Model.pkl', 'rb') as file:
    RF_PD_Model=pickle.load(file)

# %%
Logistic_regression_prediction=Logistic_PD_Model.predict(inputs)

# %%
Random_Forest_Predictions=RF_PD_Model.predict(inputs)

# %%
XGBoost_Predictions=XGBoost_PD_Model.predict(inputs)
